# %%
import pandas as pd

# %% [markdown]
# Import data

# %%
hospice_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e84610a05dba> in <module>()
# ----> 1 hospice_df
#
# NameError: name 'hospice_df' is not defined

# %%
hospice_df = pd.read_csv('data/'Hospice_General_Information.csv')
hospice_df.head(2)
# Out:
#   File "<ipython-input-2-f5d3e3083838>", line 1
#     hospice_df = pd.read_csv('data/'Hospice_General_Information.csv')
#                                                               ^
# SyntaxError: invalid syntax

# %%
hospice_df = pd.read_csv('data/'Hospice_General_Information.csv')
hospice_df.head(2)
# Out:
#   File "<ipython-input-3-f5d3e3083838>", line 1
#     hospice_df = pd.read_csv('data/'Hospice_General_Information.csv')
#                                                               ^
# SyntaxError: invalid syntax

# %%
hospice_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e84610a05dba> in <module>()
# ----> 1 hospice_df
#
# NameError: name 'hospice_df' is not defined

# %%
hospice_df = pd.read_csv('data/'Hospice_General_Information.csv')
hospice_df.head(2)
# Out:
#   File "<ipython-input-6-f5d3e3083838>", line 1
#     hospice_df = pd.read_csv('data/'Hospice_General_Information.csv')
#                                                               ^
# SyntaxError: invalid syntax

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/Users/meganvogel/vanderbilt-aspire-data-essentials'

# %%
os.chdir('/Users/meganvogel/vanderbilt-aspire-data-essentials/data')

# %%
hospice_df = pd.read_csv('Hospice_General_Information.csv')

# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-f542dbfa5144> in <module>()
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd

# %%
hospice_df.tail()
# Out:
#       CMS Certification Number (CCN)                 Facility Name  \
# 4638                          921720  COMFORTING CARE HOSPICE, INC
# 4639                          921721     BLESSED HOPE HOSPICE, INC
# 4640                          921722        VISTA HOSPICE CARE INC
# 4641                          921723          NORCAL HOSPICE, INC.
# 4642                          921729   AFFECTIVE HOSPICE CARE, INC
#
#                          Address Line 1  Address Line 2            City State  \
# 4638  5924 E LOS ANGELES AVENUE SUITE L             NaN     SIMI VALLEY    CA
# 4639       2619 S WATERMAN AVE, SUITE D             NaN  SAN BERNARDINO    CA
# 4640      550 WEST VISTA WAY, SUITE 310             NaN           VISTA    CA
# 4641       700 W. 6TH STREET, SUITE K-B             NaN          GILROY    CA
# 4642  5050 PALO VERDE STREET, SUITE 208             NaN       MONTCLAIR    CA
#
#       Zip Code     County Name     PhoneNumber  CMS Region Ownership Type  \
# ...

# %%
hospice_df = hospice_df.loc[hospice_df.State == 'TN']
hospice_df.head(1)
# Out:
#       CMS Certification Number (CCN)      Facility Name       Address Line 1  \
# 2889                          441501  ALIVE HOSPICE INC  1718 PATTERSON ROAD
#
#       Address Line 2       City State  Zip Code County Name     PhoneNumber  \
# 2889             NaN  NASHVILLE    TN     37203    Davidson  (615) 327-1085
#
#       CMS Region Ownership Type Certification Date
# 2889           4     Non-Profit         04/10/1984

# %%
#Keep only the **Facility Name**, **Address Line 1**, **City**, **State**, **County Name**, **CMS Region**, **Ownership Type**, and **Cerfification Date** columns. Make all column names lower case and without spaces. 
hospice_df.columns = ['ccn', 'facility', 'address','address2','city', 'state','zip','county','phone', 'region', 'owner_type', 'cert_date']
hospice_df.head(2)
# Out:
#          ccn                    facility                            address  \
# 2889  441501           ALIVE HOSPICE INC                1718 PATTERSON ROAD
# 2890  441502  METHODIST ALLIANCE HOSPICE  6400 SHELBY VIEW DRIVE, SUITE 101
#
#       address2       city state    zip    county           phone  region  \
# 2889       NaN  NASHVILLE    TN  37203  Davidson  (615) 327-1085       4
# 2890       NaN    MEMPHIS    TN  38134    Shelby  (901) 516-1600       4
#
#       owner_type   cert_date
# 2889  Non-Profit  04/10/1984
# 2890  Non-Profit  08/31/1984

# %%
cancer_df=pd.read_csv('data/cancer_deaths.csv', skiprows=4, nrows = 96)
cancer_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-3db02c2dfd7c> in <module>()
# ----> 1 cancer_df=pd.read_csv('data/cancer_deaths.csv', skiprows=4, nrows = 96)
#       2 cancer_df.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
cancer_df = pd.read_csv('cancer_deaths.csv', skiprows=4, nrows = 96)
cancer_df.head ()
# Out:
#              County   FIPS Met Healthy People Objective of 161.4?  \
# 0         Tennessee  47999                                     No
# 1     United States      0                                     No
# 2  Trousdale County  47169                                     No
# 3      Scott County  47151                                     No
# 4   Cheatham County  47021                                     No
#
#    Age-Adjusted Death Rate - deaths per 100,000  \
# 0                                         185.4
# 1                                         163.5
# 2                                         265.5
# 3                                         241.0
# 4                                         239.6
#
#    Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                          184.0                          186.8
# 1                          163.3                          163.7
# 2                          219.0                          319.1
# ...

# %%
cancer_df.tail ()
# Out:
#                County   FIPS Met Healthy People Objective of 161.4?  \
# 91      Sumner County  47165                                    Yes
# 92   Van Buren County  47175                                    Yes
# 93     Pickett County  47137                                    Yes
# 94     Fayette County  47047                                    Yes
# 95  Williamson County  47187                                    Yes
#
#     Age-Adjusted Death Rate - deaths per 100,000  \
# 91                                         161.2
# 92                                         160.3
# 93                                         158.7
# 94                                         154.3
# 95                                         127.2
#
#     Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 91                          153.0                          169.6
# 92                          122.7                          207.4
# ...

# %%
cancer_df.shape
# Out:
# (96, 11)

# %%
cancer_df.columns = ['county', 'fips', 'obj_met_healthy','deathrate_age_adjusted','lower95_CI', 'upper95_CI','avg_annual_count','trend','5yr_trend', 'lower95_CI.1', 'upper95_CI.1']
cancer_df.head(4)
# Out:
#              county   fips obj_met_healthy  deathrate_age_adjusted  \
# 0         Tennessee  47999              No                   185.4
# 1     United States      0              No                   163.5
# 2  Trousdale County  47169              No                   265.5
# 3      Scott County  47151              No                   241.0
#
#    lower95_CI  upper95_CI  avg_annual_count    trend  5yr_trend  lower95_CI.1  \
# 0       184.0       186.8             13933  falling       -1.4          -1.5
# 1       163.3       163.7            586354  falling       -1.5          -1.6
# 2       219.0       319.1                24   stable        0.0          -1.3
# 3       214.5       270.0                63   stable       -0.5          -1.1
#
#    upper95_CI.1
# 0          -1.2
# 1          -1.5
# 2           1.3
# 3           0.1

# %%
pop_df = pd.read_csv('PEP_2017_PEPAGESEX')
pop_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-9eb571714242> in <module>()
# ----> 1 pop_df = pd.read_csv('PEP_2017_PEPAGESEX')
#       2 pop_df.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
pop_df = pd.read_csv('PEP_2017_PEPAGESEX.csv')
pop_df.head()
# Out:
#            GEO.id GEO.id2           GEO.display-label  \
# 0              Id     Id2                   Geography
# 1  0500000US47001   47001  Anderson County, Tennessee
# 2  0500000US47003   47003   Bedford County, Tennessee
# 3  0500000US47005   47005    Benton County, Tennessee
# 4  0500000US47007   47007   Bledsoe County, Tennessee
#
#                           cen42010sex0_age999  \
# 0  April 1, 2010 - Census - Both Sexes; Total
# 1                                       75129
# 2                                       45058
# 3                                       16489
# 4                                       12876
#
#                     cen42010sex1_age999  \
# 0  April 1, 2010 - Census - Male; Total
# 1                                 36308
# 2                                 22357
# 3                                  8073
# 4                                  6964
#
#                       cen42010sex2_age999  \
# 0  April 1, 2010 - Census - Female; Total
# ...

# %%
pop_df.tail()
# Out:
#             GEO.id GEO.id2             GEO.display-label cen42010sex0_age999  \
# 91  0500000US47181   47181       Wayne County, Tennessee               17021
# 92  0500000US47183   47183     Weakley County, Tennessee               35021
# 93  0500000US47185   47185       White County, Tennessee               25841
# 94  0500000US47187   47187  Williamson County, Tennessee              183182
# 95  0500000US47189   47189      Wilson County, Tennessee              113993
#
#    cen42010sex1_age999 cen42010sex2_age999 est42010sex0_age999  \
# 91                9402                7619               17027
# 92               17159               17862               35015
# 93               12640               13201               25836
# 94               89336               93846              183252
# 95               55834               58159              114057
#
#    est42010sex1_age999 est42010sex2_age999 est72010sex0_age999  \
# ...

# %%
pop_df.shape
# Out:
# (96, 993)

# %%
hospice_df.head(5)
# Out:
#          ccn                            facility  \
# 2889  441501                   ALIVE HOSPICE INC
# 2890  441502          METHODIST ALLIANCE HOSPICE
# 2891  441504          HOSPICE OF CHATTANOOGA INC
# 2892  441506               AMEDISYS HOSPICE CARE
# 2893  441507  NORTHCREST HOME HEALTH AND HOSPICE
#
#                                 address  address2         city state    zip  \
# 2889                1718 PATTERSON ROAD       NaN    NASHVILLE    TN  37203
# 2890  6400 SHELBY VIEW DRIVE, SUITE 101       NaN      MEMPHIS    TN  38134
# 2891                 4411 OAKWOOD DRIVE       NaN  CHATTANOOGA    TN  37416
# 2892          6570 STAGE ROAD SUITE 110       NaN     BARTLETT    TN  38134
# 2893               212 NORTHCREST DRIVE       NaN  SPRINGFIELD    TN  37172
#
#          county           phone  region  owner_type   cert_date
# 2889   Davidson  (615) 327-1085       4  Non-Profit  04/10/1984
# 2890     Shelby  (901) 516-1600       4  Non-Profit  08/31/1984
# ...

# %%
hospice_df.tail(5)
# Out:
#          ccn                              facility  \
# 2940  441598        ENCOMPASS HOSPICE OF TENNESSEE
# 2941  441599                       QUALITY HOSPICE
# 2942  441600                        HEARTH HOSPICE
# 2943  441602  AMEDISYS HOSPICE, AN ADVENTA COMPANY
# 2944  441603                       KINDRED HOSPICE
#
#                             address  address2         city state    zip  \
# 2940    828 ROYAL PARKWAY SUITE 113       NaN    NASHVILLE    TN  37214
# 2941        341 WEST CENTRAL AVENUE       NaN    JAMESTOWN    TN  38556
# 2942  1800A ROSSVILLE AVE SUITE 114       NaN  CHATTANOOGA    TN  37408
# 2943              400 ROYAL PARKWAY       NaN    NASHVILLE    TN  37214
# 2944        430 STUART RD NE, STE 2       NaN    CLEVELAND    TN  37312
#
#         county           phone  region  owner_type   cert_date
# 2940  Davidson  (615) 889-3357       4  For-Profit  06/16/2010
# 2941  Fentress  (931) 879-9330       4  For-Profit  01/04/2013
# ...

# %%
hospice_df.shape
# Out:
# (56, 12)

# %%
hospice_df.drop(columns = 'ccn')
# Out:
#                                                facility  \
# 2889                                  ALIVE HOSPICE INC
# 2890                         METHODIST ALLIANCE HOSPICE
# 2891                         HOSPICE OF CHATTANOOGA INC
# 2892                              AMEDISYS HOSPICE CARE
# 2893                 NORTHCREST HOME HEALTH AND HOSPICE
# 2894                   HOSPICE OF CUMBERLAND COUNTY INC
# 2895                                  HIGHPOINT HOSPICE
# 2896                          HOSPICE OF WEST TENNESSEE
# 2897                                    KINDRED HOSPICE
# 2898                        TENNOVA HOSPICE-CLARKSVILLE
# 2899                AMEDISYS HOSPICE AN ADVENTA COMPANY
# 2900                   BLOUNT MEMORIAL HOSPITAL HOSPICE
# 2901                      ASERACARE HOSPICE - NASHVILLE
# 2902                                   SUNCREST HOSPICE
# 2903            LINCOLN MEDICAL HOME HEALTH AND HOSPICE
# 2904               AMEDISYS HOSPICE, AN ADVENTA COMPANY
# ...

# %%
hospice_df.drop(columns = 'address2','zip','phone')
# Out:
#   File "<ipython-input-36-0140db342ab7>", line 1
#     hospice_df.drop(columns = 'address2','zip','phone')
#                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
hospice_df.drop(columns = ['ccn','address2','zip','phone'])
# Out:
#                                                facility  \
# 2889                                  ALIVE HOSPICE INC
# 2890                         METHODIST ALLIANCE HOSPICE
# 2891                         HOSPICE OF CHATTANOOGA INC
# 2892                              AMEDISYS HOSPICE CARE
# 2893                 NORTHCREST HOME HEALTH AND HOSPICE
# 2894                   HOSPICE OF CUMBERLAND COUNTY INC
# 2895                                  HIGHPOINT HOSPICE
# 2896                          HOSPICE OF WEST TENNESSEE
# 2897                                    KINDRED HOSPICE
# 2898                        TENNOVA HOSPICE-CLARKSVILLE
# 2899                AMEDISYS HOSPICE AN ADVENTA COMPANY
# 2900                   BLOUNT MEMORIAL HOSPITAL HOSPICE
# 2901                      ASERACARE HOSPICE - NASHVILLE
# 2902                                   SUNCREST HOSPICE
# 2903            LINCOLN MEDICAL HOME HEALTH AND HOSPICE
# 2904               AMEDISYS HOSPICE, AN ADVENTA COMPANY
# ...

# %%
hospice_df.shape
# Out:
# (56, 12)

# %%
pop_df.head()
# Out:
#            GEO.id GEO.id2           GEO.display-label  \
# 0              Id     Id2                   Geography
# 1  0500000US47001   47001  Anderson County, Tennessee
# 2  0500000US47003   47003   Bedford County, Tennessee
# 3  0500000US47005   47005    Benton County, Tennessee
# 4  0500000US47007   47007   Bledsoe County, Tennessee
#
#                           cen42010sex0_age999  \
# 0  April 1, 2010 - Census - Both Sexes; Total
# 1                                       75129
# 2                                       45058
# 3                                       16489
# 4                                       12876
#
#                     cen42010sex1_age999  \
# 0  April 1, 2010 - Census - Male; Total
# 1                                 36308
# 2                                 22357
# 3                                  8073
# 4                                  6964
#
#                       cen42010sex2_age999  \
# 0  April 1, 2010 - Census - Female; Total
# ...

# %%
pop_df.shape
# Out:
# (96, 993)

# %%
pop_df_noapril = pop_df.drop(columns = ['cen42010sex0_age999','cen42010sex1_age999','cen42010sex2_age999','est42010sex0_age999','est42010sex1_age999','est42010sex2_age999'])

# %%
pop_df.shape
# Out:
# (96, 993)

# %%
pop_df.drop(columns = ['cen42010sex0_age999','cen42010sex1_age999','cen42010sex2_age999','est42010sex0_age999','est42010sex1_age999','est42010sex2_age999'])
pop_df.shape
# Out:
# (96, 993)

# %%
pop_df1 = pop_df[pop_df.columns.drop(list(pop_df.filter(regex='est4')))]
pop_df1.shape
# Out:
# (96, 894)

# %%
pop_df2 = pop_df1[pop_df1.columns.drop(list(pop_df1.filter(regex = '2011')))]
pop_df3 = pop_df2[pop_df2.columns.drop(list(pop_df2.filter(regex = '2012')))]
pop_df4 = pop_df3[pop_df3.columns.drop(list(pop_df3.filter(regex = '2013')))]
pop_df5 = pop_df4[pop_df4.columns.drop(list(pop_df4.filter(regex = '2015')))]
pop_df6 = pop_df5[pop_df5.columns.drop(list(pop_df5.filter(regex = '2016')))]
pop_df6.shape
# Out:
# (96, 399)

# %%
git push
# Out:
#   File "<ipython-input-59-83a80d2515aa>", line 1
#     git push
#            ^
# SyntaxError: invalid syntax
